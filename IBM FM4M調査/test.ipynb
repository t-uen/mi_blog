# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/Users/lpc_0066/Desktop/Project/IBM FM4M調査/Function summary.xlsx")
df
# Out:
#                   項目                   公開       Unnamed: 2
# 0                NaN                 単独利用  FM4M Kit ラッパー利用
# 1            SMI-TED                    ○                ○
# 2        SELFIES-TED                    ○                ○
# 3            MHG-GNN                    ○                ○
# 4           SMI-SSED                    ○                ×
# 5           POS-EGNN                    ○                ○
# 6  Multi-modal model  （sklearnのライブラリーを使用）                ○
# 7         DS Task_予測                    ○                ○
# 8        DS Task_最適化                    ×                ×

# %%
print(df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>項目</th>
#       <th>公開</th>
#       <th>Unnamed: 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>NaN</td>
#       <td>単独利用</td>
#       <td>FM4M Kit ラッパー利用</td>
#     </tr>
#     <tr>
#       <td>SMI-TED</td>
#       <td>○</td>
#       <td>○</td>
#     </tr>
#     <tr>
#       <td>SELFIES-TED</td>
#       <td>○</td>
#       <td>○</td>
#     </tr>
#     <tr>
#       <td>MHG-GNN</td>
#       <td>○</td>
#       <td>○</td>
#     </tr>
#     <tr>
#       <td>SMI-SSED</td>
#       <td>○</td>
#       <td>×</td>
#     </tr>
#     <tr>
#       <td>POS-EGNN</td>
#       <td>○</td>
#       <td>○</td>
#     </tr>
#     <tr>
#       <td>Multi-modal model</td>
#       <td>（sklearnのライブラリーを使用）</td>
#       <td>○</td>
#     </tr>
#     <tr>
#       <td>DS Task_予測</td>
#       <td>○</td>
#       <td>○</td>
#     </tr>
#     <tr>
#       <td>DS Task_最適化</td>
#       <td>×</td>
# ...
